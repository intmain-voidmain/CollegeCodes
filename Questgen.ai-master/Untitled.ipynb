# %%
from pprint import pprint
import nltk
nltk.download('stopwords')
from Questgen import main
qe= main.BoolQGen()
payload = {
            "input_text": "Oxygen is a chemical element with symbol O and atomic number 8. It is a member of the chalcogen group on the periodic table, a highly reactive nonmetal, and an oxidizing agent that readily forms oxides with most elements as well as with other compounds. By mass, oxygen is the third-most abundant element in the universe, after hydrogen and helium. At standard temperature and pressure, two atoms of the element bind to form dioxygen, a colorless and odorless diatomic gas with the formula O2. Diatomic oxygen gas constitutes 20.8% of the Earth's atmosphere. As compounds including oxides, the element makes up almost half of the Earth's crust."
        }
output = qe.predict_boolq(payload)
pprint (output)
# Out:
# [nltk_data] Downloading package stopwords to /home/rahul/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package brown to /home/rahul/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/rahul/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     /home/rahul/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     /home/rahul/nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     /home/rahul/nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     /home/rahul/nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     /home/rahul/nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /home/rahul/nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package names to /home/rahul/nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     /home/rahul/nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     /home/rahul/nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     /home/rahul/nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /home/rahul/nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package omw to /home/rahul/nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package omw-1.4 to
# [nltk_data]    |     /home/rahul/nltk_data...
# [nltk_data]    |   Package omw-1.4 is already up-to-date!
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     /home/rahul/nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet2021 to
# [nltk_data]    |     /home/rahul/nltk_data...
# [nltk_data]    |   Package wordnet2021 is already up-to-date!
# [nltk_data]    | Downloading package wordnet31 to
# [nltk_data]    |     /home/rahul/nltk_data...
# [nltk_data]    |   Package wordnet31 is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     /home/rahul/nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to /home/rahul/nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /home/rahul/nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package punkt to /home/rahul/nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /home/rahul/nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /home/rahul/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection popular
# [nltk_data] Downloading package brown to /home/rahul/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/rahul/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     /home/rahul/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     /home/rahul/nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     /home/rahul/nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     /home/rahul/nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     /home/rahul/nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /home/rahul/nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package names to /home/rahul/nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     /home/rahul/nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     /home/rahul/nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     /home/rahul/nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /home/rahul/nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package omw to /home/rahul/nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package omw-1.4 to
# [nltk_data]    |     /home/rahul/nltk_data...
# [nltk_data]    |   Package omw-1.4 is already up-to-date!
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     /home/rahul/nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet2021 to
# [nltk_data]    |     /home/rahul/nltk_data...
# [nltk_data]    |   Package wordnet2021 is already up-to-date!
# [nltk_data]    | Downloading package wordnet31 to
# [nltk_data]    |     /home/rahul/nltk_data...
# [nltk_data]    |   Package wordnet31 is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     /home/rahul/nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to /home/rahul/nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /home/rahul/nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package punkt to /home/rahul/nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /home/rahul/nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /home/rahul/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection popular
# /home/rahul/venv/lib/python3.9/site-packages/transformers/models/t5/tokenization_t5.py:164: FutureWarning: This tokenizer was incorrectly instantiated with a model max length of 512 which will be corrected in Transformers v5.
# For now, this behavior is kept to avoid breaking backwards compatibility when padding/encoding with `truncation is True`.
# - Be aware that you SHOULD NOT rely on t5-base automatically truncating your input to 512 when padding/encoding.
# - If you want to encode/pad to sequences longer than 512 you can either instantiate this tokenizer with `model_max_length` or pass `max_length` when encoding/padding.
# - To avoid this warning, please instantiate this tokenizer with `model_max_length` set to your preferred value.
#   warnings.warn(
# /home/rahul/venv/lib/python3.9/site-packages/transformers/models/t5/tokenization_t5.py:219: UserWarning: This sequence already has </s>. In future versions this behavior may lead to duplicated eos tokens being added.
#   warnings.warn(
# {'Boolean Questions': ['Is oxygen the most abundant element in the universe?',
#                        'Is hydrogen and oxygen the same thing?',
#                        'Is oxygen and hydrogen the same thing?'],
#  'Count': 4,
#  'Text': 'Oxygen is a chemical element with symbol O and atomic number 8. It '
#          'is a member of the chalcogen group on the periodic table, a highly '
#          'reactive nonmetal, and an oxidizing agent that readily forms oxides '
#          'with most elements as well as with other compounds. By mass, oxygen '
#          'is the third-most abundant element in the universe, after hydrogen '
#          'and helium. At standard temperature and pressure, two atoms of the '
#          'element bind to form dioxygen, a colorless and odorless diatomic gas '
#          'with the formula O2. Diatomic oxygen gas constitutes 20.8% of the '
#          "Earth's atmosphere. As compounds including oxides, the element makes "
#          "up almost half of the Earth's crust."}

# %%
answer = main.AnswerPredictor()
payload3 = {
    "input_text" : '''Sachin Ramesh Tendulkar is a former international cricketer from 
              India and a former captain of the Indian national team. He is widely regarded 
              as one of the greatest batsmen in the history of cricket. He is the highest
               run scorer of all time in International cricket.''',
    "input_question" : "Who is Sachin tendulkar ? "
    
}
output = answer.predict_answer(payload3)
pprint (output)
# Out:
# ('Sachin ramesh tendulkar is a former international cricketer from india and a '
#  'former captain of the indian national team.')

# %%
qg = main.QGen()
output = qg.predict_shortq(payload)
pprint (output)
# Out:
# /home/rahul/venv/lib/python3.9/site-packages/transformers/tokenization_utils_base.py:2300: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
# Running model for generation
# {'questions': [{'Question': "What is the element that makes up almost half of the Earth's crust?", 'Answer': 'oxides', 'id': 1, 'context': "It is a member of the chalcogen group on the periodic table, a highly reactive nonmetal, and an oxidizing agent that readily forms oxides with most elements as well as with other compounds. As compounds including oxides, the element makes up almost half of the Earth's crust."}, {'Question': 'What is the most abundant element in the universe?', 'Answer': 'helium', 'id': 2, 'context': 'By mass, oxygen is the third-most abundant element in the universe, after hydrogen and helium.'}, {'Question': "What makes up almost half of the Earth's crust?", 'Answer': 'compounds', 'id': 3, 'context': "It is a member of the chalcogen group on the periodic table, a highly reactive nonmetal, and an oxidizing agent that readily forms oxides with most elements as well as with other compounds. As compounds including oxides, the element makes up almost half of the Earth's crust."}, {'Question': 'What is the most abundant element in the universe?', 'Answer': 'hydrogen', 'id': 4, 'context': 'By mass, oxygen is the third-most abundant element in the universe, after hydrogen and helium.'}]}
# {'questions': [{'Answer': 'oxides',
#                 'Question': 'What is the element that makes up almost half of '
#                             "the Earth's crust?",
#                 'context': 'It is a member of the chalcogen group on the '
#                            'periodic table, a highly reactive nonmetal, and an '
#                            'oxidizing agent that readily forms oxides with '
#                            'most elements as well as with other compounds. As '
#                            'compounds including oxides, the element makes up '
#                            "almost half of the Earth's crust.",
#                 'id': 1},
#                {'Answer': 'helium',
#                 'Question': 'What is the most abundant element in the '
#                             'universe?',
#                 'context': 'By mass, oxygen is the third-most abundant element '
#                            'in the universe, after hydrogen and helium.',
#                 'id': 2},
#                {'Answer': 'compounds',
#                 'Question': "What makes up almost half of the Earth's crust?",
#                 'context': 'It is a member of the chalcogen group on the '
#                            'periodic table, a highly reactive nonmetal, and an '
#                            'oxidizing agent that readily forms oxides with '
#                            'most elements as well as with other compounds. As '
#                            'compounds including oxides, the element makes up '
#                            "almost half of the Earth's crust.",
#                 'id': 3},
#                {'Answer': 'hydrogen',
#                 'Question': 'What is the most abundant element in the '
#                             'universe?',
#                 'context': 'By mass, oxygen is the third-most abundant element '
#                            'in the universe, after hydrogen and helium.',
#                 'id': 4}],
#  'statement': 'Oxygen is a chemical element with symbol O and atomic number 8. '
#               'It is a member of the chalcogen group on the periodic table, a '
#               'highly reactive nonmetal, and an oxidizing agent that readily '
#               'forms oxides with most elements as well as with other '
#               'compounds. By mass, oxygen is the third-most abundant element '
#               'in the universe, after hydrogen and helium. At standard '
#               'temperature and pressure, two atoms of the element bind to form '
#               'dioxygen, a colorless and odorless diatomic gas with the '
#               'formula O2. Diatomic oxygen gas constitutes 20.8% of the '
#               "Earth's atmosphere. As compounds including oxides, the element "
#               "makes up almost half of the Earth's crust."}

# %%
qg = main.QGen()
output = qg.predict_mcq(payload)
pprint (output.get("questions"))
# Out:
# Running model for generation
#  Sense2vec_distractors successful for word :  oxides
#  Sense2vec_distractors successful for word :  helium
#  Sense2vec_distractors successful for word :  compounds
#  Sense2vec_distractors successful for word :  hydrogen
# [{'answer': 'oxides',
#   'context': 'It is a member of the chalcogen group on the periodic table, a '
#              'highly reactive nonmetal, and an oxidizing agent that readily '
#              'forms oxides with most elements as well as with other compounds. '
#              'As compounds including oxides, the element makes up almost half '
#              "of the Earth's crust.",
#   'extra_options': ['Metal Ions',
#                     'Impurities',
#                     'Silica',
#                     'Polymers',
#                     'Oxidized'],
#   'id': 1,
#   'options': ['Iron Oxide', 'Alumina', 'Argon'],
#   'options_algorithm': 'sense2vec',
#   'question_statement': 'What is the element that makes up almost half of the '
#                         "Earth's crust?",
#   'question_type': 'MCQ'},
#  {'answer': 'helium',
#   'context': 'By mass, oxygen is the third-most abundant element in the '
#              'universe, after hydrogen and helium.',
#   'extra_options': ['Rocket Fuel', 'Methane'],
#   'id': 2,
#   'options': ['Hydrogen', 'Deuterium', 'Gasses'],
#   'options_algorithm': 'sense2vec',
#   'question_statement': 'What is the most abundant element in the universe?',
#   'question_type': 'MCQ'},
#  {'answer': 'compounds',
#   'context': 'It is a member of the chalcogen group on the periodic table, a '
#              'highly reactive nonmetal, and an oxidizing agent that readily '
#              'forms oxides with most elements as well as with other compounds. '
#              'As compounds including oxides, the element makes up almost half '
#              "of the Earth's crust.",
#   'extra_options': ['Substrates'],
#   'id': 3,
#   'options': ['Other Chemicals', 'Alkaloids', 'Peptides'],
#   'options_algorithm': 'sense2vec',
#   'question_statement': "What makes up almost half of the Earth's crust?",
#   'question_type': 'MCQ'},
#  {'answer': 'hydrogen',
#   'context': 'By mass, oxygen is the third-most abundant element in the '
#              'universe, after hydrogen and helium.',
#   'extra_options': ['Methane', 'Nitrogen', 'Oxidizer', 'Fuel Cell'],
#   'id': 4,
#   'options': ['Deuterium', 'Hydrocarbons', 'Liquid Fuel'],
#   'options_algorithm': 'sense2vec',
#   'question_statement': 'What is the most abundant element in the universe?',
#   'question_type': 'MCQ'}]

# %%
qg = main.QGen()
output = qg.predict_mcq(payload)
pprint (output)
# Out:
# Running model for generation
#  Sense2vec_distractors successful for word :  oxides
#  Sense2vec_distractors successful for word :  helium
#  Sense2vec_distractors successful for word :  compounds
#  Sense2vec_distractors successful for word :  hydrogen
# {'questions': [{'answer': 'oxides',
#                 'context': 'It is a member of the chalcogen group on the '
#                            'periodic table, a highly reactive nonmetal, and an '
#                            'oxidizing agent that readily forms oxides with '
#                            'most elements as well as with other compounds. As '
#                            'compounds including oxides, the element makes up '
#                            "almost half of the Earth's crust.",
#                 'extra_options': ['Metal Ions',
#                                   'Impurities',
#                                   'Silica',
#                                   'Polymers',
#                                   'Oxidized'],
#                 'id': 1,
#                 'options': ['Iron Oxide', 'Alumina', 'Argon'],
#                 'options_algorithm': 'sense2vec',
#                 'question_statement': 'What is the element that makes up '
#                                       "almost half of the Earth's crust?",
#                 'question_type': 'MCQ'},
#                {'answer': 'helium',
#                 'context': 'By mass, oxygen is the third-most abundant element '
#                            'in the universe, after hydrogen and helium.',
#                 'extra_options': ['Rocket Fuel', 'Methane'],
#                 'id': 2,
#                 'options': ['Hydrogen', 'Deuterium', 'Gasses'],
#                 'options_algorithm': 'sense2vec',
#                 'question_statement': 'What is the most abundant element in '
#                                       'the universe?',
#                 'question_type': 'MCQ'},
#                {'answer': 'compounds',
#                 'context': 'It is a member of the chalcogen group on the '
#                            'periodic table, a highly reactive nonmetal, and an '
#                            'oxidizing agent that readily forms oxides with '
#                            'most elements as well as with other compounds. As '
#                            'compounds including oxides, the element makes up '
#                            "almost half of the Earth's crust.",
#                 'extra_options': ['Substrates'],
#                 'id': 3,
#                 'options': ['Other Chemicals', 'Alkaloids', 'Peptides'],
#                 'options_algorithm': 'sense2vec',
#                 'question_statement': 'What makes up almost half of the '
#                                       "Earth's crust?",
#                 'question_type': 'MCQ'},
#                {'answer': 'hydrogen',
#                 'context': 'By mass, oxygen is the third-most abundant element '
#                            'in the universe, after hydrogen and helium.',
#                 'extra_options': ['Methane',
#                                   'Nitrogen',
#                                   'Oxidizer',
#                                   'Fuel Cell'],
#                 'id': 4,
#                 'options': ['Deuterium', 'Hydrocarbons', 'Liquid Fuel'],
#                 'options_algorithm': 'sense2vec',
#                 'question_statement': 'What is the most abundant element in '
#                                       'the universe?',
#                 'question_type': 'MCQ'}],
#  'statement': 'Oxygen is a chemical element with symbol O and atomic number 8. '
#               'It is a member of the chalcogen group on the periodic table, a '
#               'highly reactive nonmetal, and an oxidizing agent that readily '
#               'forms oxides with most elements as well as with other '
#               'compounds. By mass, oxygen is the third-most abundant element '
#               'in the universe, after hydrogen and helium. At standard '
#               'temperature and pressure, two atoms of the element bind to form '
#               'dioxygen, a colorless and odorless diatomic gas with the '
#               'formula O2. Diatomic oxygen gas constitutes 20.8% of the '
#               "Earth's atmosphere. As compounds including oxides, the element "
#               "makes up almost half of the Earth's crust.",
#  'time_taken': 10.94347858428955}
