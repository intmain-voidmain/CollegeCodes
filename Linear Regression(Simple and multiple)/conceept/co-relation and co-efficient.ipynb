# %%
import matplotlib.pyplot as plt 
import  pandas as pd

# %%
df=pd.read_csv("test.csv")
df
# Out:
#     A   B
# 0   8  10
# 1   9  12
# 2  10  14
# 3  11  16
# 4  12  18

# %%
x_train=df.drop('B',axis=1)
y_train=df.drop('A',axis=1)
print(x_train)
print(y_train)
# Out:
#     A
# 0   8
# 1   9
# 2  10
# 3  11
# 4  12
#     B
# 0  10
# 1  12
# 2  14
# 3  16
# 4  18

# %%
from sklearn import linear_model 
model=linear_model.LinearRegression()
model.fit(x_train,y_train)  # ( independt   , dependt )
# Out:
# LinearRegression()

# %%
#A and B relation 
#b=coefficent
print(model.coef_)
# Out:
# [[2.]]

# %%
print(model.intercept_)
# Out:
# [-6.]

# %% [markdown]
# Intercept Concept(When x is 0 so y=Intercept)

# %% [markdown]
# ![download.png](attachment:download.png)

# %%
#x=1 and y=2.1 as per csv file 
import seaborn as sns 
sns.scatterplot(x="A",y="B",data=df,color='g',label="original value ")
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %% [markdown]
# # Co-relation Co-efficient formula

# %% [markdown]
# ![corelation.png](attachment:corelation.png)
