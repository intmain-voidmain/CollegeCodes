# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
my_data = pd.read_csv('district wise rainfall normal.csv')
my_data
# Out:
#                    STATE_UT_NAME        DISTRICT    JAN   FEB    MAR    APR  \
# 0    ANDAMAN And NICOBAR ISLANDS         NICOBAR  107.3  57.9   65.2  117.0
# 1    ANDAMAN And NICOBAR ISLANDS   SOUTH ANDAMAN   43.7  26.0   18.6   90.5
# 2    ANDAMAN And NICOBAR ISLANDS   N & M ANDAMAN   32.7  15.9    8.6   53.4
# 3              ARUNACHAL PRADESH           LOHIT   42.2  80.8  176.4  358.5
# 4              ARUNACHAL PRADESH      EAST SIANG   33.3  79.5  105.9  216.5
# ..                           ...             ...    ...   ...    ...    ...
# 636                       KERALA          IDUKKI   13.4  22.1   43.6  150.4
# 637                       KERALA        KASARGOD    2.3   1.0    8.4   46.9
# 638                       KERALA  PATHANAMTHITTA   19.8  45.2   73.9  184.9
# 639                       KERALA         WAYANAD    4.8   8.3   17.5   83.3
# 640                  LAKSHADWEEP     LAKSHADWEEP   20.8  14.7   11.8   48.9
#
# ...

# %% [markdown]
# # Bar Plot annual rainfall for each DISTRICT of SIKKIM, WEST BENGAL, MEGHALAYA

# %%
plt.figure(figsize=(10,10))

sikkim = my_data[my_data.STATE_UT_NAME.isin(['SIKKIM'])]
sikkim_x = sikkim.DISTRICT
sikkim_y = sikkim.ANNUAL
plt.barh(sikkim_x,sikkim_y,color = 'r')

wb = my_data[my_data.STATE_UT_NAME.isin(['WEST BENGAL'])]
wb_x = wb.DISTRICT
wb_y = wb.ANNUAL
plt.barh(wb_x,wb_y,color = 'g')

mg = my_data[my_data.STATE_UT_NAME.isin(['MEGHALAYA'])]
mg_x = mg.DISTRICT
mg_y = mg.ANNUAL
plt.barh(mg_x,mg_y,color = 'b')

plt.show()

# %%
wb1 = my_data[my_data.STATE_UT_NAME.isin(['WEST BENGAL'])]
wb_x = wb1.DISTRICT
wb_y_jun = wb1.JUN
plt.plot(wb_x,wb_y_jun,color = 'g')

wb2 = my_data[my_data.STATE_UT_NAME.isin(['WEST BENGAL'])]
wb_x = wb2.DISTRICT
wb_y = wb2.JUL
plt.plot(wb_x,wb_y,color = 'b')

plt.grid(True)
plt.xticks(rotation = 60)
plt.show()

# %%
wb3 = my_data[my_data.STATE_UT_NAME.isin(['WEST BENGAL'])]
wb_x = wb3.DISTRICT
jan_feb= wb3['Jan-Feb']
mar_may = wb3['Mar-May']
jun_sep=wb3['Jun-Sep']
oct_dec=wb3['Oct-Dec']
plt.plot(wb_x,jan_feb,color='r')
plt.plot(wb_x,mar_may,color='b')
plt.plot(wb_x,jun_sep,color='g')
plt.plot(wb_x,oct_dec,color='y')
plt.xticks(rotation=60)
plt.grid()
plt.show()
